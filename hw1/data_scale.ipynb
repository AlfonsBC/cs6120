# %% [markdown]
# Homework 1: Python, Strings, Data, Scale
# ----
#
# Due date: Jan 19th, 2024, 11:59 PM
#
# Points: 42
#
# Files to submit:
# - `data_scale.ipynb`
# - `kjv.txt` (See task 3. This file will most likely be a `.txt` or `.csv`, but can be any)
#
# Goals:
# - ensure that your python environment is set up and running
# - learn/review python skills regarding `string`s, data structures, and file manipulation
#
# Complete in groups of: __one (individually)__
#
# Allowed python modules:
# - Note that all necessary modules have already been imported for you for this assignment. (you may import any standard python libraries, plotting libraries as you'd like)
#
#
# Instructions:
# - Complete outlined problems in this notebook.
# - When you have finished, __clear the kernel__ and run your notebook "fresh" from top to bottom. Ensure that there are __no errors__.
#     - If a problem asks for you to write code that does result in an error (as in, the answer to the problem is an error), leave the code in your notebook but commented out so that running from top to bottom does not result in any errors.
# - Double check that you have completed Task 0.
# - Submit your work on Gradescope.
# - Double check that your submission on Gradescope looks like you believe it should.

# %% [markdown]
# Task 0: Name, References, Reflection (5 points)
# ---
#
# **TODO:** complete this section
#
# **Name: Alfonso Barajas Cervantes**
#
# References
# ---
# List the resources you consulted to complete this homework here. Write one sentence per resource about what it provided to you. If you consulted no references to complete your assignment, write a brief sentence stating that this is the case and why it was the case for you.
#
# - [O-Bible](https://www.o-bible.com)
#   Obtain text resource to work on
# - [guru99](https://www.guru99.com/python-file-readline.html)
#   Guide to read files with python using `readline()` methods
# - [DigitalOcean](https://www.digitalocean.com/community/tutorials/python-join-list)
#   A refresher of how the method `join` works
#
# (Example)
# - https://docs.python.org/3/tutorial/datastructures.html
#     - Read about the the basics and syntax for data structures in python.
#
# AI Collaboration
# ---
#
# I *recommend* not using LLMs to aid in this homework but instead use the documentation linked below, since it is vital for you to learn how to use Python properly. If, however, you get stuck and use generative AI or LLMs to help you complete this assignment, remember to cite it here with a short description of what you used it for, and which other resources you consulted (if any).
#
# Reflection
# ----
# Answer the following questions __after__ you complete this assignment (no more than 1 sentence per question required, this section is graded on completion):
#
# 1. Does this work reflect your best effort?
#
#    Yes, the work i did reflect my best effort to solve tasks.
# 2. What was/were the most challenging part(s) of the assignment?
#
#    I would say that reading the file was a little bit difficult as it took me more time to read the files and the cleaning so it can be read to our counting tokenizer method.
#
# 3. If you want feedback, what function(s) or problem(s) would you like feedback on and why?
#
#    I would like if possible, some feedback on the way I read the file was the most efficient. It seems that it is, but would like to know if there are other ways to make it faster when there is massive texts to work on.

# %% [markdown]
# Task 1: Python Warm-up (8 points)
# ----
#
# We'll warm-up by either learning about or reviewing `string`s, `for` loops, `range()`, and `list`s.
#
# Links to relevant documentation:
# - [strings](https://docs.python.org/3/library/string.html)
# - [Prof. Felix Muzny's notes on strings](https://muzny.github.io/csci1200-notes/03/5/strings.html)
# - [for loops](https://wiki.python.org/moin/ForLoop)
# - [Prof. Felix Muzny's notes on for loops](https://muzny.github.io/csci1200-notes/08/1/for_loops_basics.html)
# - [lists](https://docs.python.org/3/tutorial/datastructures.html)
# - [Prof. Felix Muzny's notes on lists](https://muzny.github.io/csci1200-notes/07/1/lists_basics.html)

# %%
# define a string variable, then
# using a for loop, iterate through the letters of a string
x1 = "BayesianProbability"
for element in x1:
    print(element)
# Out:
# B
# a
# y
# e
# s
# i
# a
# n
# P
# r
# o
# b
# a
# b
# i
# l
# i
# t
# y

# %%
# define a list variable, then
# using a for loop, iterate through the contents of a list
x2 = ['I', 'love', 'Math', 'and', 7, 'Science']
for element in x2:
    print(element)
# Out:
# I
# love
# Math
# and
# 7
# Science

# %%
# define a string variable, then
# using a for loop and the range() function, print out every other token 
# (you may assume tokens are separated by spaces) in the string
x3 = "Non parametric statitics"
n = len(x3)
for i in range(n):
    print(x3[i])
# Out:
# N
# o
# n
#
# p
# a
# r
# a
# m
# e
# t
# r
# i
# c
#
# s
# t
# a
# t
# i
# t
# i
# c
# s

# %% [markdown]
# The split method has an argument where we can split by an element such as a white space ' ' or it can be eben an element such as '='

# %%
# demonstrate the difference(s) between calling python's 
# str.split() function like str.split(' ') and str.split()
x4 = "Non parametric statitics"
print(x4.split(' '))
x5 = "Statitics=and=Probability"
print(x5.split())
print(x5.split('='))
# Out:
# ['Non', 'parametric', 'statitics']
# ['Statitics=and=Probability']
# ['Statitics', 'and', 'Probability']

# %% [markdown]
# Task 2: Timing Python Functions (15 points)
# ----
#
# In this section, we'll explore efficiency and python data structures.
# You'll work on increasing your familiarity with `list`s, `dict`s, and [`Counter`](https://docs.python.org/3/library/collections.html#collections.Counter)s.
#
# Notice that in our python function headers, we include [type hints](https://docs.python.org/3/library/typing.html).

# %%
# for timing
import time

# for our fancier data structure
from collections import Counter

# for type hinting
from typing import Callable

# for graphing
import matplotlib.pyplot as plt

# for random number generation
import random
import numpy as np

# %%
# provided
def timer(fun: Callable, tokens: list) -> float:
    """
    measure (in seconds) the time that it takes to run a
    function that operates on a list of strings (tokens)

    Args:
    fun: Callable
    tokens: list

    return:
    float (seconds)
    """
    start = time.time()
    fun(tokens)
    end = time.time()
    return end - start

# call like 
# len is the funtion that is being timed
print("That took:", timer(len, ["this", "is", "a", "test"]), "seconds!")
# Out:
# That took: 9.5367431640625e-07 seconds!

# %%
# TODO: implement the following functions (function signatures are provided for you)
def count_list(tokens: list) -> dict:
    """
    Count the number of occurrences of each token in a list of tokens.
    Use the list.count() method.

    Args:
    tokens: list of items (often tokens)

    return:
    dict (mapping from token to count)
    """
    # YOUR CODE HERE
    # getting unique tokens
    unique = set(tokens)
    # initializing dict
    output = {}
    for i in unique:
        count = tokens.count(i)
        output[i] = count
    return output
    

def count_dict(tokens: list) -> dict:
    """
    Count the number of occurrences of each token in a list of tokens.
    Do not use the list.count() method. Do not use a Counter.
    If you would like to use any method/function other than len, it must be
    okay'd with the teaching staff.

    Args:
    tokens: list of items (often tokens)

    return:
    dict (mapping from token to count)
    """
    # YOUR CODE HERE
    output = {}
    for element in tokens:
        if element in output:
            output[element] +=1
        else:
            output[element] =1
    return output

def count_counter(tokens: list) -> Counter:
    """
    Count the number of occurrences of each token in a list of tokens.
    Use a Counter.
    Do not use the list.count() method or any other list/dict functions/methods.

    Args:
    tokens: list of items (often tokens)

    return:
    Counter (mapping from token to count)
    """
    # YOUR CODE HERE
    return Counter(tokens)

# %%
# TODO: verify that your count_* functions are correct and consistent with one another

# Make sure to test both if the list does not have duplicates and if it does

# %%
print("That took:", timer(count_list, ["this", "is", "a", "test", "a", "is", "is", "this"]), "seconds!")
# Out:
# That took: 5.9604644775390625e-06 seconds!

# %%
count_list(["this", "is", "a", "test", "a", "is", "is", "this"])
# Out:
# {'this': 2, 'a': 2, 'test': 1, 'is': 3}

# %%
count_list(["this", "is", "a", "test"])
# Out:
# {'this': 1, 'a': 1, 'test': 1, 'is': 1}

# %%
print("That took:", timer(count_dict, ["this", "is", "a", "test", "a", "is", "is", "this"]), "seconds!")
# Out:
# That took: 4.0531158447265625e-06 seconds!

# %%
count_dict(["this", "is", "a", "test", "a", "is", "is", "this"])
# Out:
# {'this': 2, 'is': 3, 'a': 2, 'test': 1}

# %%
count_dict(["this", "is", "a", "test"])
# Out:
# {'this': 1, 'is': 1, 'a': 1, 'test': 1}

# %%
print("That took:", timer(count_counter, ["this", "is", "a", "test", "a", "is", "is", "this"]), "seconds!")
# Out:
# That took: 5.817413330078125e-05 seconds!

# %%
count_counter(["this", "is", "a", "test", "a", "is", "is", "this"])
# Out:
# Counter({'is': 3, 'this': 2, 'a': 2, 'test': 1})

# %%
count_counter(["this", "is", "a", "test"])
# Out:
# Counter({'this': 1, 'is': 1, 'a': 1, 'test': 1})

# %%
# TODO: create a graph with three lines, one for each of the three count_* functions
# x-axis should be the number of items in the list given to the function (go up to at least 500)
# y-axis should be the time taken to run the function
# the graph should have a legend indicating which line is which (use plt.legend() to make this happen)
listtimes = []
dicttimes = []
countertimes = []

# you'll need to generate one (or more) list(s) of items to be counted.
# we recommend using the random module to generate random integers
times = {}
for n in range(0,600, 50):
    items = [random.randint(0, 10) for i in range(10 + n)]
    a = timer(count_list, items)
    listtimes.append(a)
    b = timer(count_dict, items)
    dicttimes.append(b)
    c = timer(count_counter, items)
    countertimes.append(c)

# %%
plt.plot(range(0,600, 50),listtimes, label="List method")
plt.plot(range(0,600, 50),dicttimes, label="Dict method")
plt.plot(range(0,600, 50),countertimes, label="Counter method")
plt.title("Time comparison against three methods in seconds")
plt.ylabel("Time in seconds [s]")
plt.xlabel("Size of items to be counted")
plt.legend()
plt.show()

# %% [markdown]
# Task 3: Real World Data (8 points)
# ----
#
# In this section, you'll find some real world text data *of interest to you* and run some analysis on this data. The data that you choose can include labels, but if it does, do not include those labels in your counts of tokens, etc.
#
#
# Size requirements:
# - your file must contain a minimum of 10,000 tokens (as measured by at least *one* of your tokenization schemes).
#
#
# Key vocabulary:
#
# __token__: The unit that we will operate on when processing text. Normally corresponds roughly to "words", and you can assume that this is the case for this homework.

# %%
# TODO
# the file should be in the same folder as this notebook because when you 
# submit this notebook, you will also submit the file and the backend of the 
# system expects them to be in the same directory
FILE = "./kjv.txt"

# %%
# read the contents of your file in, however you'd like
myfile = open(FILE, "r") 
# reading the line of our file 
myline = myfile.readline()
final_string = ''
counter_lines = 1
# making a loop until it finishes
while myline:
    # Cleaning labels (Books and chapters of the bible)
    cleaned = myline.split(' ', 1)[1]
    final_string += cleaned
    myline = myfile.readline()
    counter_lines += 1
myfile.close()

# %%
# how many lines are in your file?
print("There are ", str(counter_lines), " lines in the KJV Bible")
# Out:
# There are  31103  lines in the KJV Bible

# %%
final_list = final_string.split("\n")

# %%
len(final_list)
# Out:
# 31103

# %%
last_list = [i.split(' ') for i in final_list]

# %%
list_bible = []
for i in last_list:
    list_bible += i

# %%
print("There are ",len(list_bible), " words")
# Out:
# There are  789639  words

# %%
# tokenize your data using the str.split() function. How many tokens are there?
dict_token =  count_counter(list_bible)

# %%
print("There are ",len(dict_token)," tokens")
# Out:
# There are  28855  tokens

# %%
dict_token
# Out:
# Counter({'the': 62051,
#          'and': 38572,
#          'of': 34393,
#          'to': 13367,
#          'And': 12739,
#          'that': 12454,
#          'in': 12167,
#          'shall': 9759,
#          'he': 9509,
#          'unto': 8933,
#          'I': 8707,
#          'his': 8363,
#          'a': 7945,
#          'for': 7141,
#          'they': 6893,
#          'be': 6717,
#          'is': 6696,
#          'with': 5951,
#          'not': 5840,
#          'all': 5238,
#          'thou': 4629,
#          'it': 4461,
#          'thy': 4453,
#          'was': 4445,
#          'which': 4268,
#          'my': 4134,
#          'LORD': 3928,
#          'their': 3873,
#          'have': 3822,
#          'will': 3752,
#          'from': 3578,
#          'ye': 3566,
#          'them': 3503,
#          'as': 3256,
#          'him': 3158,
#          'are': 2883,
#          'upon': 2715,
#          'were': 2712,
#          'by': 2493,
#          'when': 2483,
#          'out': 2459,
#          'but': 2410,
#          'said': 2280,
#          'this': 2271,
#          'God': 2230,
#          'hath': 2216,
#          'him,': 2036,
#          'into': 2011,
#          'had': 1994,
#          'came': 1989,
#          'man': 1971,
#          'on': 1924,
#          'up': 1898,
#          'there': 1861,
#          'The': 1843,
#          'me': 1777,
#          'your': 1753,
#          'before': 1745,
#          'king': 1735,
#          'one': 1709,
#          'said,': 1681,
#          'an': 1673,
#          'For': 1670,
#          'son': 1658,
#          'against': 1654,
#          'shalt': 1614,
#          'we': 1609,
#          'them,': 1608,
#          'children': 1587,
#          'But': 1542,
#          'thee': 1529,
#          'come': 1520,
#          'her': 1515,
#          'at': 1502,
#          'also': 1422,
#          'LORD,': 1405,
#          'Then': 1373,
#          'made': 1333,
#          'went': 1327,
#          'no': 1318,
#          'house': 1314,
#          'saying,': 1285,
#          'even': 1237,
#          'people': 1226,
#          'thee,': 1214,
#          'me,': 1197,
#          'every': 1178,
#          'saith': 1167,
#          'you': 1165,
#          'do': 1148,
#          'land': 1142,
#          'our': 1131,
#          'if': 1104,
#          'Israel': 1097,
#          'men': 1092,
#          'go': 1085,
#          'after': 1079,
#          'let': 1078,
#          'O': 1065,
#          'day': 1057,
#          'or': 1054,
#          'hast': 1027,
#          'may': 1023,
#          'make': 1002,
#          'because': 999,
#          'God,': 965,
#          'over': 956,
#          'so': 940,
#          'these': 936,
#          'she': 917,
#          'did': 907,
#          'among': 903,
#          'any': 900,
#          'thine': 882,
#          'put': 880,
#          'hand': 865,
#          'great': 858,
#          'brought': 852,
#          'down': 847,
#          'sons': 839,
#          'you,': 835,
#          'am': 816,
#          'him.': 815,
#          'us': 799,
#          'things': 791,
#          'two': 778,
#          'give': 777,
#          'Jesus': 775,
#          'neither': 774,
#          'should': 768,
#          'Israel,': 767,
#          'according': 762,
#          'He': 753,
#          'then': 751,
#          'nor': 747,
#          'took': 742,
#          'forth': 736,
#          'whom': 723,
#          'take': 702,
#          'David': 694,
#          'them.': 689,
#          'therefore': 682,
#          'who': 681,
#          'bring': 676,
#          'know': 675,
#          'Lord': 669,
#          'set': 666,
#          'sent': 655,
#          'name': 654,
#          'like': 645,
#          'what': 643,
#          'Now': 622,
#          'So': 621,
#          'LORD.': 621,
#          'say': 617,
#          'away': 608,
#          'it,': 602,
#          'behold,': 601,
#          'heard': 574,
#          'own': 573,
#          'Thou': 573,
#          'called': 571,
#          'mine': 570,
#          'word': 557,
#          'yet': 552,
#          'days': 551,
#          'now': 541,
#          'people,': 531,
#          'more': 528,
#          'me.': 526,
#          'saw': 524,
#          'spake': 524,
#          'Behold,': 522,
#          'hundred': 509,
#          'good': 503,
#          'thee.': 494,
#          'eat': 489,
#          'If': 484,
#          'God.': 484,
#          'Moses': 483,
#          'given': 482,
#          'than': 482,
#          'cast': 478,
#          'heart': 469,
#          'see': 466,
#          'gave': 464,
#          'many': 459,
#          'city': 450,
#          'Thus': 448,
#          'those': 444,
#          'about': 440,
#          'time': 436,
#          'would': 434,
#          'three': 434,
#          'evil': 434,
#          'might': 434,
#          'seven': 432,
#          'art': 429,
#          'Let': 428,
#          'through': 428,
#          'it.': 427,
#          'other': 423,
#          'man,': 422,
#          'father': 419,
#          'done': 414,
#          'thousand': 411,
#          'They': 404,
#          'place': 403,
#          'Therefore': 400,
#          'pass': 400,
#          'pass,': 397,
#          'way': 396,
#          'house,': 395,
#          'answered': 386,
#          'under': 385,
#          'holy': 382,
#          'without': 377,
#          'commanded': 377,
#          'Judah': 372,
#          'say,': 370,
#          'words': 368,
#          'offering': 367,
#          'how': 367,
#          'thing': 365,
#          'off': 365,
#          'again': 362,
#          'burnt': 360,
#          'found': 357,
#          'speak': 357,
#          'first': 356,
#          'When': 349,
#          'midst': 348,
#          'until': 348,
#          'toward': 346,
#          'both': 342,
#          'Israel.': 338,
#          'In': 336,
#          'That': 332,
#          'himself': 332,
#          'keep': 330,
#          'years': 330,
#          'earth': 329,
#          'This': 328,
#          'What': 328,
#          'voice': 326,
#          'him:': 326,
#          'high': 324,
#          'day,': 323,
#          'thereof': 323,
#          'been': 322,
#          'where': 321,
#          'five': 321,
#          'cities': 321,
#          'you.': 321,
#          'hear': 320,
#          'none': 320,
#          'dwell': 317,
#          'cut': 315,
#          'right': 315,
#          'round': 315,
#          'thereof,': 313,
#          'stood': 313,
#          'priest': 311,
#          'servant': 306,
#          'them:': 305,
#          'hand,': 304,
#          'us,': 303,
#          'land,': 302,
#          'Judah,': 295,
#          'four': 293,
#          'same': 292,
#          'work': 290,
#          'soul': 290,
#          'men,': 288,
#          'up,': 288,
#          'taken': 287,
#          'me:': 287,
#          'whose': 284,
#          'hands': 284,
#          'Ye': 282,
#          'blood': 282,
#          "king's": 282,
#          'young': 281,
#          'LORD:': 280,
#          'pray': 280,
#          'sin': 279,
#          'cause': 278,
#          'eyes': 276,
#          'son,': 276,
#          'twenty': 276,
#          'being': 276,
#          'law': 276,
#          'Jerusalem,': 276,
#          'told': 275,
#          'king,': 275,
#          'face': 273,
#          'fire': 273,
#          'servants': 272,
#          'fear': 271,
#          'them;': 270,
#          'brethren,': 270,
#          'city,': 269,
#          'left': 269,
#          'and,': 267,
#          'Who': 267,
#          'side': 267,
#          'her,': 267,
#          'deliver': 267,
#          'thus': 266,
#          'themselves': 265,
#          'turned': 265,
#          'LORD;': 265,
#          'laid': 265,
#          'glory': 265,
#          'delivered': 264,
#          'old': 263,
#          'not,': 261,
#          'Saul': 261,
#          'chief': 258,
#          'very': 257,
#          'gathered': 256,
#          'earth,': 256,
#          'kings': 255,
#          'As': 255,
#          'year': 254,
#          'priests': 254,
#          'kingdom': 253,
#          'Moses,': 252,
#          'much': 251,
#          'Christ': 251,
#          'thee:': 249,
#          'Egypt,': 247,
#          'Lord,': 247,
#          'daughter': 246,
#          'mighty': 245,
#          'turn': 245,
#          'another': 244,
#          'Jerusalem': 243,
#          'woman': 240,
#          'such': 240,
#          'together': 238,
#          'It': 237,
#          'end': 237,
#          'destroy': 236,
#          'Son': 236,
#          'ten': 235,
#          'Wherefore': 234,
#          'drink': 234,
#          'tabernacle': 234,
#          'My': 233,
#          'A': 233,
#          'between': 232,
#          'wicked': 232,
#          'seen': 230,
#          'love': 230,
#          'smote': 227,
#          'fell': 227,
#          'tribe': 227,
#          'These': 226,
#          'whole': 226,
#          'concerning': 226,
#          'full': 226,
#          'begat': 225,
#          'lay': 225,
#          'offer': 225,
#          'yea,': 224,
#          'cometh': 223,
#          'flesh': 222,
#          'seek': 222,
#          'mouth': 221,
#          'spirit': 220,
#          'little': 220,
#          'mount': 219,
#          'fathers': 219,
#          'meat': 218,
#          'spoken': 218,
#          'shew': 215,
#          'dwelt': 214,
#          'him;': 212,
#          'There': 212,
#          'heaven,': 212,
#          'can': 211,
#          'peace': 210,
#          'thee;': 209,
#          'wilt': 207,
#          'God:': 206,
#          'save': 206,
#          'some': 206,
#          'David,': 206,
#          'heaven': 205,
#          'stand': 204,
#          'Solomon': 204,
#          'seed': 203,
#          'covenant': 203,
#          'sight': 203,
#          'send': 203,
#          'Aaron': 203,
#          'day.': 202,
#          'lest': 202,
#          'Because': 201,
#          'heart,': 201,
#          'We': 200,
#          'rest': 199,
#          'altar': 199,
#          'come,': 199,
#          'head': 199,
#          'inhabitants': 198,
#          'life': 197,
#          'bread': 197,
#          'mercy': 196,
#          'brethren': 195,
#          'bear': 195,
#          'people.': 195,
#          'written': 195,
#          'surely': 194,
#          'All': 194,
#          'offering,': 194,
#          'strong': 194,
#          'part': 193,
#          'fathers,': 192,
#          'fall': 191,
#          'slew': 191,
#          'earth.': 190,
#          'serve': 190,
#          'Jacob': 190,
#          'sat': 188,
#          'gone': 188,
#          'certain': 188,
#          'brother': 187,
#          'waters': 185,
#          'thou,': 185,
#          'father,': 185,
#          'doth': 184,
#          'not.': 184,
#          'known': 184,
#          'princes': 183,
#          'return': 182,
#          'things,': 182,
#          'nations': 182,
#          'down,': 182,
#          'ever.': 182,
#          'cannot': 181,
#          'Of': 180,
#          'Go': 180,
#          'tell': 180,
#          'congregation': 180,
#          'above': 179,
#          'six': 179,
#          'walk': 179,
#          'though': 178,
#          'wise': 178,
#          'it:': 177,
#          'ark': 177,
#          'angel': 177,
#          'To': 177,
#          'me;': 176,
#          'power': 176,
#          'How': 174,
#          'water': 173,
#          'bare': 173,
#          'having': 173,
#          'out,': 173,
#          'began': 172,
#          'gold,': 172,
#          'call': 171,
#          'praise': 171,
#          'sword': 170,
#          'Jerusalem.': 170,
#          'reigned': 168,
#          'within': 167,
#          'well': 167,
#          'wife': 166,
#          'kept': 166,
#          'multitude': 166,
#          'sons,': 165,
#          'gate': 165,
#          'Israel:': 165,
#          'third': 164,
#          'knew': 164,
#          'could': 164,
#          'long': 164,
#          'sacrifice': 163,
#          'light': 162,
#          'till': 161,
#          'throughout': 161,
#          'receive': 160,
#          'house.': 160,
#          'hold': 160,
#          'Joshua': 159,
#          'departed': 158,
#          'passed': 158,
#          'lifted': 158,
#          'it;': 158,
#          'while': 158,
#          'cried': 158,
#          'fruit': 156,
#          'manner': 156,
#          'thirty': 155,
#          'righteous': 155,
#          'whether': 155,
#          'judgment': 155,
#          'only': 154,
#          'Is': 154,
#          'Take': 154,
#          'you:': 154,
#          'built': 153,
#          'far': 153,
#          'sea': 153,
#          'blessed': 152,
#          'wherein': 152,
#          'forty': 152,
#          'Egypt': 152,
#          'able': 152,
#          'place,': 151,
#          'together,': 151,
#          'find': 151,
#          'judge': 149,
#          'Thy': 149,
#          'received': 148,
#          'build': 147,
#          'hand.': 147,
#          'Levites': 146,
#          'gold': 145,
#          'inheritance': 145,
#          'way,': 144,
#          'gather': 144,
#          'near': 144,
#          'carried': 144,
#          'new': 144,
#          'Jews': 144,
#          'sea,': 143,
#          'Israel;': 143,
#          'disciples': 143,
#          'book': 142,
#          'us.': 142,
#          'returned': 141,
#          'also,': 141,
#          'dead': 141,
#          'Christ,': 141,
#          'second': 140,
#          'daughters': 140,
#          'land.': 140,
#          'Holy': 140,
#          'thereof.': 139,
#          'why': 139,
#          'lord': 139,
#          'righteousness': 139,
#          'days,': 138,
#          'filled': 138,
#          'nothing': 138,
#          'again,': 138,
#          'enter': 137,
#          'away,': 137,
#          'number': 137,
#          'commandment': 137,
#          'Be': 136,
#          'Why': 136,
#          'anger': 136,
#          'Moreover': 136,
#          'elders': 136,
#          'whatsoever': 135,
#          'become': 135,
#          'now,': 135,
#          'thyself': 135,
#          'Philistines': 135,
#          'Joseph': 135,
#          'silver': 135,
#          'prophet': 135,
#          'law,': 134,
#          'men.': 134,
#          'door': 133,
#          'broken': 133,
#          'border': 133,
#          'children,': 133,
#          'strength': 133,
#          'priest,': 133,
#          'servants,': 132,
#          'Father': 132,
#          'whosoever': 131,
#          "father's": 131,
#          'burn': 131,
#          'must': 131,
#          'faith': 131,
#          'eyes,': 130,
#          'not:': 130,
#          'most': 130,
#          'shewed': 130,
#          'sword,': 129,
#          'works': 129,
#          'meet': 128,
#          'rose': 128,
#          'born': 128,
#          'slain': 128,
#          'lie': 128,
#          'wrath': 128,
#          'goeth': 127,
#          'twelve': 127,
#          'offerings': 127,
#          'God;': 127,
#          'break': 127,
#          'half': 127,
#          'offered': 126,
#          'thee?': 126,
#          'iniquity': 126,
#          'Which': 126,
#          'places': 126,
#          'fifty': 125,
#          'maketh': 125,
#          'ever': 125,
#          'unclean': 125,
#          'name,': 124,
#          'silver,': 124,
#          'sought': 124,
#          'month,': 123,
#          'look': 123,
#          'behold': 123,
#          'cry': 123,
#          'Spirit': 122,
#          'night': 122,
#          'Pharaoh': 122,
#          'captain': 122,
#          'beside': 122,
#          'die': 122,
#          'poor': 122,
#          'giveth': 122,
#          'didst': 121,
#          'mother': 120,
#          'Abraham': 120,
#          'voice,': 120,
#          'wife,': 119,
#          'Blessed': 119,
#          'me?': 119,
#          'GOD;': 119,
#          'hosts,': 119,
#          "man's": 118,
#          'wilderness': 118,
#          'vessels': 118,
#          'host': 117,
#          'dead,': 117,
#          'Yet': 117,
#          'fire,': 117,
#          'feet': 116,
#          'that,': 115,
#          'yourselves': 115,
#          'himself,': 115,
#          'wisdom': 115,
#          'Jesus,': 115,
#          'grace': 114,
#          'child': 114,
#          'One': 114,
#          'prophets': 114,
#          'seventh': 113,
#          'field': 113,
#          'mayest': 113,
#          'destroyed': 113,
#          'death': 113,
#          'world': 113,
#          'smite': 112,
#          'fine': 112,
#          'living': 111,
#          'hid': 111,
#          'war': 111,
#          'enemies': 111,
#          'therefore,': 111,
#          'asked': 111,
#          'lo,': 110,
#          'rise': 110,
#          'throne': 110,
#          'rejoice': 110,
#          'family': 110,
#          'leave': 109,
#          'this,': 109,
#          'Peter': 109,
#          'kill': 108,
#          'walked': 108,
#          'numbered': 108,
#          'counsel': 108,
#          'Babylon': 108,
#          'spread': 107,
#          'time,': 107,
#          'servant,': 107,
#          'stone': 107,
#          'became': 106,
#          'hearken': 106,
#          'appointed': 106,
#          'bless': 106,
#          'slay': 105,
#          'And,': 105,
#          'another,': 105,
#          'Jacob,': 105,
#          'wherewith': 105,
#          'priests,': 105,
#          'earth:': 104,
#          'not;': 104,
#          'whither': 104,
#          'water,': 104,
#          'opened': 103,
#          'flesh,': 103,
#          'followed': 103,
#          'live': 102,
#          'Neither': 102,
#          'wine': 102,
#          'Jeremiah': 102,
#          'river': 101,
#          'east': 101,
#          'beasts': 101,
#          'in,': 101,
#          'entered': 101,
#          'he,': 101,
#          'answered,': 101,
#          'side,': 101,
#          'Samuel': 101,
#          'Babylon,': 101,
#          'fat': 100,
#          'looked': 100,
#          'possess': 100,
#          'reign': 100,
#          'trust': 100,
#          'cubits': 99,
#          'believe': 99,
#          'congregation,': 99,
#          'field,': 98,
#          'Yea,': 98,
#          'brother,': 98,
#          'valley': 98,
#          'her.': 98,
#          'wilderness,': 98,
#          'witness': 98,
#          'night,': 97,
#          'open': 97,
#          'trees': 97,
#          'I,': 97,
#          'sweet': 97,
#          'back': 97,
#          'women': 97,
#          'knoweth': 97,
#          'is,': 97,
#          'truth': 97,
#          'Aaron,': 97,
#          'month': 97,
#          'sabbath': 97,
#          'king.': 97,
#          'temple': 97,
#          'help': 96,
#          'Also': 96,
#          'Even': 96,
#          'saying': 96,
#          'sit': 96,
#          'offerings,': 96,
#          'captains': 96,
#          'Hezekiah': 96,
#          'Paul': 96,
#          'life,': 95,
#          'go,': 95,
#          'blood,': 95,
#          'seeing': 95,
#          'mouth,': 95,
#          'ears': 95,
#          'worship': 95,
#          'world,': 95,
#          'morning': 94,
#          'caused': 94,
#          'shut': 94,
#          'Egypt.': 94,
#          'bound': 94,
#          'death.': 94,
#          'better': 94,
#          'answer': 94,
#          'gods': 94,
#          'teach': 94,
#          'tree': 93,
#          'remember': 93,
#          'buried': 93,
#          'feast': 93,
#          'be,': 93,
#          "LORD's": 93,
#          'wall': 93,
#          'joy': 93,
#          'fled': 92,
#          'command': 92,
#          'service': 92,
#          'utterly': 92,
#          'beast': 91,
#          'man.': 91,
#          'bread,': 91,
#          'forth,': 91,
#          'sun': 91,
#          'him?': 91,
#          'ought': 91,
#          'peace,': 91,
#          'afraid': 91,
#          'fight': 91,
#          'knowledge': 90,
#          'gods,': 90,
#          'covered': 90,
#          'altar,': 90,
#          'morning,': 90,
#          'wrought': 90,
#          'people:': 90,
#          'Saul,': 90,
#          'desire': 89,
#          'died': 89,
#          'south': 89,
#          'place.': 89,
#          'body': 89,
#          'Christ.': 89,
#          'heart.': 88,
#          'families': 88,
#          'top': 88,
#          'away.': 88,
#          'His': 88,
#          'chosen': 88,
#          'days.': 87,
#          'you;': 87,
#          'money': 87,
#          'about,': 87,
#          'oil': 87,
#          'ye,': 87,
#          'wherefore': 86,
#          'going': 86,
#          'prepared': 86,
#          'threescore': 86,
#          'ways': 86,
#          'Jonathan': 86,
#          'thing,': 85,
#          'hands,': 85,
#          'lift': 85,
#          'believed': 85,
#          'drew': 85,
#          'words,': 85,
#          'stones': 85,
#          'never': 85,
#          'sing': 85,
#          'death,': 85,
#          'saith,': 85,
#          'Joab': 85,
#          'head,': 84,
#          'Hear': 84,
#          'years,': 84,
#          'By': 84,
#          'there.': 84,
#          'nations,': 84,
#          'Give': 84,
#          'arose,': 84,
#          'Surely': 84,
#          'prince': 84,
#          'loved': 84,
#          'came,': 84,
#          'arose': 84,
#          'Levites,': 84,
#          'sins': 84,
#          'wait': 84,
#          'hope': 84,
#          'thence': 83,
#          'ever:': 83,
#          'mountains': 83,
#          'wine,': 83,
#          'flee': 83,
#          'doeth': 83,
#          'present': 83,
#          'carry': 83,
#          'nigh': 83,
#          'burned': 83,
#          'remnant': 83,
#          'John': 83,
#          'country': 82,
#          'here': 82,
#          'Abraham,': 82,
#          'wash': 82,
#          'us:': 82,
#          'poured': 82,
#          'times': 82,
#          'incense': 82,
#          'presence': 81,
#          'Come': 81,
#          'ready': 81,
#          'get': 81,
#          'there,': 81,
#          'again.': 81,
#          'themselves,': 81,
#          'ask': 81,
#          'hosts': 81,
#          'commandments': 81,
#          'minister': 81,
#          'declare': 80,
#          'plague': 80,
#          'prophets,': 80,
#          'tongue': 80,
#          'everlasting': 79,
#          'city.': 79,
#          'portion': 79,
#          'face,': 79,
#          'good,': 79,
#          'bringeth': 79,
#          'charge': 79,
#          'raised': 79,
#          'noise': 79,
#          'pure': 79,
#          'heaven.': 78,
#          'evil,': 78,
#          'life.': 78,
#          'pitched': 78,
#          'Shall': 78,
#          'small': 78,
#          'tribes': 78,
#          'spoil': 78,
#          'fire.': 78,
#          'righteousness,': 78,
#          'Jeroboam': 78,
#          'Father,': 78,
#          'day:': 77,
#          'hearkened': 77,
#          'earth;': 77,
#          'tenth': 77,
#          'depart': 77,
#          'firstborn': 77,
#          'hate': 77,
#          'Ephraim': 77,
#          'houses': 77,
#          'honour': 77,
#          'sound': 77,
#          'years.': 76,
#          'things.': 76,
#          'all.': 76,
#          'people;': 76,
#          'hand:': 76,
#          'up.': 76,
#          'committed': 76,
#          'suffer': 76,
#          'eye': 76,
#          'north': 76,
#          'Woe': 76,
#          'gates': 76,
#          'woman,': 75,
#          'mother,': 75,
#          'After': 75,
#          'hide': 75,
#          "mother's": 75,
#          'name.': 75,
#          'strange': 75,
#          'nation': 75,
#          'oil,': 75,
#          'coming': 75,
#          'offering:': 74,
#          'Behold': 74,
#          'son.': 74,
#          'sore': 74,
#          'taketh': 74,
#          'understanding': 74,
#          'all,': 74,
#          'fourth': 73,
#          'breadth': 73,
#          'bowed': 73,
#          'sheep': 73,
#          'out.': 73,
#          'atonement': 73,
#          'Jordan': 73,
#          'feet,': 72,
#          'abide': 72,
#          'sold': 72,
#          'come.': 72,
#          'thought': 72,
#          'commit': 72,
#          'Selah.': 72,
#          'cattle': 71,
#          'Where': 71,
#          'shouldest': 71,
#          'land:': 71,
#          'sware': 71,
#          'stretched': 71,
#          'house:': 71,
#          'Pharaoh,': 71,
#          'enemies,': 71,
#          'Moses.': 71,
#          'court': 71,
#          'lips': 71,
#          'disciples,': 71,
#          'die.': 70,
#          'wind': 70,
#          'removed': 70,
#          'served': 70,
#          'prophet,': 70,
#          'feed': 70,
#          'ruler': 70,
#          'cover': 70,
#          'ways,': 70,
#          'temple,': 70,
#          'beginning': 69,
#          'eaten': 69,
#          'clothed': 69,
#          'year,': 69,
#          'Jordan,': 69,
#          'consumed': 69,
#          'sin,': 69,
#          'reason': 69,
#          'trespass': 69,
#          'salvation': 69,
#          'taught': 69,
#          'prayer': 69,
#          'whereof': 68,
#          ...})

# %% [markdown]
# Find five specific examples of difficult-to-tokenize sequences of words in your data.
# - Example 1. We can see that the words `and` and `And` are the same but just with different first letter, one is in uppercase and the other in lowercase.
# - Example 2. We can notice that the token `LORD` appears $3,928$ times which is the name of God, Jehova, but there are other $1,405$ to be added for the token `LORD,` and `LORD.` which account for $621$. Leaving us with $5,954$ times.
# - Example 3. We should take special care when dealing with the token `LORD` and `Lord` as their concept actually is different and we would not want to lowercase all. `LORD` refers to God, the creator of the Universe and `Lord` refers to Jesus Christ of Nazareth that was resurrected. This is adding to the tokenization the prior knowledge.
# - Example 4. We notice the same with `God` and `God.`
# - Example 5. We can notice some tokens having problems with the punctuation `,`,`.`, `;` and uppercase and lowercase problems such as `up` and `up.` or `Christ` and `Christ.`

# %% [markdown]
# Task 4: Data Write-Up (6 points)
# ---
#
# Every time you use a data set in an NLP application (or in any software application), you should be able to answer a set of questions about that data. Answer these now. Default to no more than 1 sentence per question needed. If more explanation is necessary, do give it.

# %% [markdown]
# 1. Where did you get the data from?
#
#    I got the King James Version of the Bible on the site [O-Bible](https://www.o-bible.com) where there are other versions ready to download such as Interlinear or Chinese versions.
#
# 2. How was the data collected (where did the people acquiring the data get it from and how)?
#
#    This group pre-process the Holy Bible KJV version to a text file.
#
# 3. How large is the dataset? (copy # of lines and # of tokens from above)
#
#    The number of lines are $31,103$. There are $789,639$ words and $28,855$ tokens.
#
# 4. Is your dataset a subset of a larger dataset or the entirety of a dataset? (e.g. the first half of reviews from the dataset.... vs. all reviews from ...)
#
#    The dataset i had worked on is the _full_ Holy Bible King James
#
# 5. What is your data? (i.e. newswire, tweets, books, blogs, etc)
#
#    The data that i worked on is the Bible which is a collection of books divinely inspired by God.
#
# 6. Who produced the data? (who were the authors of the text? Your answer might be a specific person or a particular group of people)
#
#    It has been a collection of books starting from the Jews and now from different groups of persons that follows a particular storyline which is the Kingdom of God where Jesus is the King. These historical stories have been here across 4000 years. The data, the Holy Bible is divinely inspired by God as it contains prophesies that actually happened and are about to happen.
